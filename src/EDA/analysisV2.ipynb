# %%
import numpy as np
import pandas as pd
import nltk as nlt
import json
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = "../../data/processed/nvidia_grouped_preprocessed/posts_by_month.json"

with open(file_path, "r", encoding="utf-8") as file:
    json_data = json.load(file)

# Flatten into a single list of all posts
all_posts = []
for month, posts in json_data.items():
    all_posts.extend(posts)  # Combine all posts into one list

# Create DataFrame
df = pd.DataFrame(all_posts)

# %%
df.head()
# Out:
#      month                                              title        date  \
# 0  2025-04      game ready  studio driver 57602 faqdiscussion  2025-04-16
# 1  2025-04  tech support and question megathread  april 20...  2025-04-01
# 2  2025-04  rtx 5070 ti performance scaling 57602 vs 57283...  2025-04-19
# 3  2025-04                                 5090 storm trooper  2025-04-19
# 4  2025-04                                     5090 astral lc  2025-04-18
#
#        time  score  num_comments         flair  \
# 0  17:47:13    589          2181    Discussion
# 1  10:45:43      6            29  Tech Support
# 2  01:35:23    348            89    Benchmarks
# 3  04:54:58     93            15  Build/Photos
# 4  21:01:07    210           116  Build/Photos
#
#                                                 body  \
# 0   game ready  studio driver 57602 has been rele...
# 1  were consolidating all tech support posts and ...
# 2  on the day of the release of the new nvidia dr...
# 3  this is my first time hard tubing and its been...
# 4  astral 5090 lc installed today  using hwmonito...
#
#                                        combined_text comments
# 0  game ready  studio driver 57602 faqdiscussion ...       []
# 1  tech support and question megathread  april 20...       []
# 2  rtx 5070 ti performance scaling 57602 vs 57283...       []
# 3  5090 storm trooper this is my first time hard ...       []
# 4  5090 astral lc astral 5090 lc installed today ...       []

# %% [markdown]
# # Text Based Analysis

# %%
text = df["combined_text"]

# %%
from collections import Counter
import re

# Total character counts per post
character_count = list(map(lambda x:len(x),text))

df["character_count"] = character_count

# Total word count per post
word_counts = list(map(lambda s: len(s.split()), text))
df["Word_count"] = word_counts

# Seperated Words from total list
words = [word.lower() for t in text for word in re.findall(r'\b\w+\b', t)]
# df["Sepeated_words"] = words

# Sepeated words PER list
words_per_list = []
for t in text:
    words_per_list.append([text.lower() for text in re.findall(r'\b\w+\b', t)])

df["Seperated_List"] = words_per_list

# Frequncy of words in the entire dataframe
word_freq_counts = Counter(words)

# %%
# nlt.download('stopwords',download_dir="/src/EDA")
df.head()
# Out:
#      month                                              title        date  \
# 0  2025-04      game ready  studio driver 57602 faqdiscussion  2025-04-16
# 1  2025-04  tech support and question megathread  april 20...  2025-04-01
# 2  2025-04  rtx 5070 ti performance scaling 57602 vs 57283...  2025-04-19
# 3  2025-04                                 5090 storm trooper  2025-04-19
# 4  2025-04                                     5090 astral lc  2025-04-18
#
#        time  score  num_comments         flair  \
# 0  17:47:13    589          2181    Discussion
# 1  10:45:43      6            29  Tech Support
# 2  01:35:23    348            89    Benchmarks
# 3  04:54:58     93            15  Build/Photos
# 4  21:01:07    210           116  Build/Photos
#
#                                                 body  \
# 0   game ready  studio driver 57602 has been rele...
# 1  were consolidating all tech support posts and ...
# 2  on the day of the release of the new nvidia dr...
# 3  this is my first time hard tubing and its been...
# 4  astral 5090 lc installed today  using hwmonito...
#
#                                        combined_text comments  \
# 0  game ready  studio driver 57602 faqdiscussion ...       []
# 1  tech support and question megathread  april 20...       []
# 2  rtx 5070 ti performance scaling 57602 vs 57283...       []
# 3  5090 storm trooper this is my first time hard ...       []
# 4  5090 astral lc astral 5090 lc installed today ...       []
#
#    character_count  Word_count  \
# 0             9756        1595
# 1             4162         683
# 2              486          81
# 3              539         102
# 4              245          43
#
#                                       Seperated_List
# 0  [game, ready, studio, driver, 57602, faqdiscus...
# 1  [tech, support, and, question, megathread, apr...
# 2  [rtx, 5070, ti, performance, scaling, 57602, v...
# 3  [5090, storm, trooper, this, is, my, first, ti...
# 4  [5090, astral, lc, astral, 5090, lc, installed...

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))  # Load English stopwords
words = [w for w in words if w not in stop_words]
print(words)
word_freq_counts = Counter(words)
most_common = word_freq_counts.most_common(20)  

common_words_df = pd.DataFrame(most_common, columns=['Word', 'Frequency'])
common_words_df.head()
# Out:
# ['game', 'ready', 'studio', 'driver', '57602', 'faqdiscussion', 'game', 'ready', 'studio', 'driver', '57602', 'released', 'two', 'pages', 'worth', 'fixes', 'cannot', 'find', 'driver', 'nvidia', 'website', 'search', 'showing', 'nvidia', 'app', 'please', 'give', 'time', 'propagate', 'article', 'link', 'game', 'ready', 'driver', 'direct', 'download', 'link', 'link', 'studio', 'driver', 'direct', 'download', 'link', 'link', 'new', 'feature', 'fixes', 'driver', '57602', 'game', 'ready', 'new', 'game', 'ready', 'driver', 'supports', 'new', 'geforce', 'rtx', '5060', 'ti', 'gpu', 'provides', 'best', 'gaming', 'experience', 'latest', 'new', 'games', 'supporting', 'dlss', '4', 'technology', 'including', 'black', 'myth', 'wukong', 'room', 'hell', '2', 'gaming', 'technology', 'adds', 'support', 'geforce', 'rtx', '5060', 'ti', 'applications', 'april', 'nvidia', 'studio', 'driver', 'offers', 'support', 'new', 'geforce', 'rtx', '5060', 'ti', 'well', 'latest', 'new', 'creative', 'applications', 'updates', 'fixed', 'gaming', 'bugs', 'fortnite', 'random', 'crashes', 'gameplay', '5171520', 'first', 'berserker', 'khazan', 'dxgi_error_device_removed', 'crash', '5195216', 'star', 'wars', 'outlaws', 'application', 'freeze', 'leaving', 'game', 'idle', '5', 'minutes', '5191099', 'game', 'stability', 'issues', 'playing', 'games', 'dlss', 'frame', 'generation', 'gsync', '5144337', 'monster', 'hunter', 'wilds', 'crash', 'accepting', 'quest', 'dlssfg', 'enabled', '5087795', 'inzoi', 'game', 'crashes', 'error', 'gpu', 'crashed', 'd3d', 'device', 'removed', '5154864', 'overwatch', '2', 'stutter', 'using', 'vsync', '5171856', 'hellblade', '2', 'senuas', 'saga', 'increased', 'aliasing', 'using', 'tsr', '5125662', 'hellblade', '2', 'senuas', 'saga', 'crashing', 'using', 'smooth', 'motion', '5209772', 'last', 'us', 'part', '1', 'crash', 'using', 'smooth', 'motion', '5208799', 'ditheringbanding', 'games', 'rtx', '50series', 'gpus', '5121715', 'control', 'flickering', 'corruption', 'multiple', 'areas', '5118876', 'stutter', 'using', 'vsync', '52027035202474', 'vsync', 'nvcp', 'frame', 'generation', 'causes', 'issues', 'dlss', '4', 'games', '5124816', 'uncharted', 'legacy', 'thieves', 'collection', 'artifacts', 'screen', 'collecting', 'treasures', '5158954', 'fixed', 'general', 'bugs', 'stability', 'issues', 'using', 'windows', '11', '24h2', '5160948', 'bugcheck', 'w', 'page_fault_in_nonpaged_area', '50', 'playing', 'games', 'dlss', '4', 'multiframe', 'generation', '5144337', 'rtx', '50', 'series', 'gpus', 'crashes', 'black', 'screenunderflow', '5160845', 'rtx', '50', 'series', 'random', 'black', 'screen', 'issues', '5090505', 'general', 'system', 'stability', 'issues', '4921925', 'rtx', '50', 'series', 'system', 'hard', 'hang', '57216', 'driver', 'loaded', '5107271', 'compute', 'shader', 'related', 'tests', 'failing', 'due', 'error', '4894179', 'hwbudt', 'gb202203lg', '27gn950', 'specific', 'display', 'blacked', 'applying', '120hz', 'refresh', 'rate', '5044229', 'pc', 'display', 'wake', 'extended', 'sleep', 'time', '5131052', 'two', 'dp', 'output', 'rtx5090', 'blue', 'screen', 'trying', 'watch', 'protected', 'videos', '5167145', 'black', 'screen', 'issue', 'testing', '3d', 'mark', 'driver', '57202', '57216', '5095825', 'primary', 'blank', 'display', 'showing', 'blank', 'hot', 'plug', 'display', 'daisy', 'chain', '4978206', 'display', 'shows', 'blank', 'screen', 'setting', 'rr', '165200hz', 'daisy', 'chain', 'enabled', '5049227', 'second', 'display', 'showing', 'blank', 'apply', 'higher', 'rr', 'second', 'display', 'displays', 'connected', 'daisy', 'chain', '4956573', 'primary', 'monitor', 'aorous', 'fo32u2p', 'goes', 'blank', 'hpdpower', 'cycle', 'second', 'display', 'daisy', 'chain', '5075448', 'geforce', 'rtx', '50', 'series', 'gpus', 'crashes', 'black', 'screen', 'playing', 'graphically', 'demanding', 'games', '5098914', 'rtx', '50', 'series', 'displays', 'blank', 'screens', 'lg', '5k2k', '45gx950ab', 'running', 'displayport', '21', 'mode', 'w', 'hdr', '519267 ...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aayus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
#      Word  Frequency
# 0     rtx        115
# 1     gpu        104
# 2  nvidia         82
# 3      im         81
# 4     get         77

# %%
from nltk.util import ngrams

# Generate unigrams, bigrams, trigrams
unigrams = list(ngrams(words, 1))
bigrams = list(ngrams(words, 2))
trigrams = list(ngrams(words, 3))

# Count most common n-grams

grams_df = pd.DataFrame()
grams_df["bigrams"] = Counter(bigrams).most_common(20)
grams_df["trigrams"] = Counter(trigrams).most_common(20)
grams_df.head()
# Out:
#                      bigrams                       trigrams
# 0         ((50, series), 30)        ((rtx, 50, series), 19)
# 1            ((rtx, 50), 19)  ((inflation, cost, 2018), 10)
# 2           ((5060, ti), 18)           ((rtx, 5070, ti), 8)
# 3  ((frame, generation), 18)           ((rtx, 5060, ti), 6)
# 4           ((5070, ti), 16)  ((nvidia, control, panel), 6)

# %% [markdown]
# #### So bascailly, in addidtion to the relvent data from data frame, i also need to give
# #### Bigrams, trigrams, most coommon words

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

sent = df['combined_text'].apply(lambda post: sia.polarity_scores(post)['compound'])
print(sent)
# Out:
# 0      0.9463
# 1      0.9957
# 2      0.3182
# 3      0.8063
# 4      0.4372
#         ...
# 167    0.5754
# 168   -0.4767
# 169    0.0000
# 170   -0.7060
# 171   -0.9646
# Name: combined_text, Length: 172, dtype: float64

# %%
df["Sentiment"] = sent

# %%
df.head()
# Out:
#      month                                              title        date  \
# 0  2025-04      game ready  studio driver 57602 faqdiscussion  2025-04-16
# 1  2025-04  tech support and question megathread  april 20...  2025-04-01
# 2  2025-04  rtx 5070 ti performance scaling 57602 vs 57283...  2025-04-19
# 3  2025-04                                 5090 storm trooper  2025-04-19
# 4  2025-04                                     5090 astral lc  2025-04-18
#
#        time  score  num_comments         flair  \
# 0  17:47:13    589          2181    Discussion
# 1  10:45:43      6            29  Tech Support
# 2  01:35:23    348            89    Benchmarks
# 3  04:54:58     93            15  Build/Photos
# 4  21:01:07    210           116  Build/Photos
#
#                                                 body  \
# 0   game ready  studio driver 57602 has been rele...
# 1  were consolidating all tech support posts and ...
# 2  on the day of the release of the new nvidia dr...
# 3  this is my first time hard tubing and its been...
# 4  astral 5090 lc installed today  using hwmonito...
#
#                                        combined_text comments  \
# 0  game ready  studio driver 57602 faqdiscussion ...       []
# 1  tech support and question megathread  april 20...       []
# 2  rtx 5070 ti performance scaling 57602 vs 57283...       []
# 3  5090 storm trooper this is my first time hard ...       []
# 4  5090 astral lc astral 5090 lc installed today ...       []
#
#    character_count  Word_count  \
# 0             9756        1595
# 1             4162         683
# 2              486          81
# 3              539         102
# 4              245          43
#
#                                       Seperated_List  Sentiment
# 0  [game, ready, studio, driver, 57602, faqdiscus...     0.9463
# 1  [tech, support, and, question, megathread, apr...     0.9957
# 2  [rtx, 5070, ti, performance, scaling, 57602, v...     0.3182
# 3  [5090, storm, trooper, this, is, my, first, ti...     0.8063
# 4  [5090, astral, lc, astral, 5090, lc, installed...     0.4372

# %%
###-------------------------------------------------------CHATGPT COPY PASTE HO I AINT TAKING NO ACCOUNTABILITY-----------------------------------------------------


# Assuming the DataFrame is already loaded as df
# # Create a new column for post length (character count in the 'body' column)
df['post_length'] = df['body'].apply(len)

# Extract hour from the 'time' column
df['hour'] = pd.to_datetime(df['time'], format='%H:%M:%S').dt.hour

# Analyze sentiment vs post length
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='post_length', y='Sentiment')
plt.title('Sentiment vs Post Length')
plt.xlabel('Post Length')
plt.ylabel('Sentiment')
plt.show()

# Analyze sentiment vs time of day
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='hour', y='Sentiment')
plt.title('Sentiment vs Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Sentiment')
plt.show()

# Analyze sentiment vs popularity (score and num_comments)
df['popularity'] = df['score'] + df['num_comments']

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='popularity', y='Sentiment')
plt.title('Sentiment vs Popularity (Score + Comments)')
plt.xlabel('Popularity (Score + Comments)')
plt.ylabel('Sentiment')
plt.show()

# Correlations (Post length, Time, Popularity with Sentiment)
correlations = df[['post_length', 'hour', 'popularity', 'Sentiment']].corr()
print(correlations)
# Out:
#              post_length      hour  popularity  Sentiment
# post_length     1.000000 -0.002091    0.015879   0.178520
# hour           -0.002091  1.000000    0.024986   0.073958
# popularity      0.015879  0.024986    1.000000  -0.164840
# Sentiment       0.178520  0.073958   -0.164840   1.000000

# %%
relevant_columns = ['date', 'score', 'num_comments', 'flair','character_count','Word_count', 'Sentiment','post_length','hour', "popularity"]
new_df = df[relevant_columns]
new_df.head()
# Out:
#          date  score  num_comments         flair  character_count  Word_count  \
# 0  2025-04-16    589          2181    Discussion             9756        1595
# 1  2025-04-01      6            29  Tech Support             4162         683
# 2  2025-04-19    348            89    Benchmarks              486          81
# 3  2025-04-19     93            15  Build/Photos              539         102
# 4  2025-04-18    210           116  Build/Photos              245          43
#
#    Sentiment  post_length  hour  popularity
# 0     0.9463         9710    17        2770
# 1     0.9957         4105    10          35
# 2     0.3182          431     1         437
# 3     0.8063          520     4         108
# 4     0.4372          230    21         326

# %%
import os
import json

path = "../../data/PostEDA"
processed_dir = path
os.makedirs(processed_dir, exist_ok=True)

# Convert DataFrames to dictionaries or lists of dictionaries
with open(os.path.join(processed_dir, 'relevent_dataframe.json'), 'w') as f:
    json.dump(new_df.to_dict(orient='records'), f, indent=2)

with open(os.path.join(processed_dir, 'ngrams.json'), 'w') as f:
    json.dump(grams_df.to_dict(orient='records'), f, indent=2)

with open(os.path.join(processed_dir, 'most_common_words.json'), 'w') as f:
    json.dump(common_words_df.to_dict(orient='records'), f, indent=2)
